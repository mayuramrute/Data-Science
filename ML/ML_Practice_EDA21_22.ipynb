# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Survived.unique()
# Out:
# array([0, 1, 2, 4])

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    545
# 1    344
# 2      1
# 4      1
# Name: count, dtype: int64

# %% [markdown]
# # Categotrical Data univariate

# %% [markdown]
# ## countplot

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df.Survived.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
sns.countplot(x='Survived', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = df['Embarked'], data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [raw]
# Here in the count plot the variable which we want to count needs to put in x axis and its count will be on y axis

# %% [markdown]
# ## piechart

# %% [markdown]
# ### this will give the percentage wise distribution of categories

# %%
df['Survived'].value_counts().plot(kind='pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## numerical data univariate

# %% [markdown]
# ### Histogram
# #### plt.hist()

# %% [raw]
# histogram this is present in matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
 plt.hist(df['Age'], bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.hist(df['Fare'])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### distplot()

# %% [markdown]
# ##### this is similar to the histogram having the KDE
# #### sns.distplot()

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_12212\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### boxplot()
# #### sns.boxplot()
# ##### used to find the outliers from the data

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(x = 'Age', data = df)
# Out:
# <Axes: xlabel='Age'>

# %%
np.round(df.describe(), 1)
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# count        891.0     891.0   891.0  714.0  891.0  891.0  891.0
# mean         446.0       0.4     2.3   29.7    0.5    0.4   32.2
# std          257.4       0.5     0.8   14.5    1.1    0.8   49.7
# min            1.0       0.0     1.0    0.4    0.0    0.0    0.0
# 25%          223.5       0.0     2.0   20.1    0.0    0.0    7.9
# 50%          446.0       0.0     3.0   28.0    0.0    0.0   14.5
# 75%          668.5       1.0     3.0   38.0    1.0    0.0   31.0
# max          891.0       4.0     3.0   80.0    8.0    6.0  512.3

# %% [markdown]
# # Multivariate analysis

# %% [markdown]
# ## scatterplot

# %% [raw]
# it is used to finfd out the ralation ship between the variables i.e how they are ralated to each other

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
 sns.scatterplot(x= tips['total_bill'], y = tips['tip'])   # two data represented
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [raw]
#  from above graph we can say that the two variables are linearlt related to each other

# %%
sns.scatterplot(x= tips['total_bill'], y = tips['tip'], hue = tips['sex'])     # three variable represented
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x= tips['total_bill'], y = tips['tip'], hue = tips['sex'], style = tips['smoker'])  # four variables
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x= tips['total_bill'], y = tips['tip'], hue = tips['sex'], style=tips['smoker'], size = tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Barplot(Numeric-categorical)

# %%
sns.barplot(x = df['Pclass'], y = df['Age'])  # bivariate
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=df['Pclass'], y=df['Age'], hue=df['Gender'])    # three variables are represented
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ## Boxplot()

# %% [markdown]
# #### categorical and number

# %%
sns.boxplot(x = df['Gender'],y = df['Age'])   # bivariate
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x = df['Pclass'], y=df['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x = df['Pclass'], y=df['Age'], hue=df['Gender'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x = df['Gender'],y = df['Age'], hue = df['Survived'])
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %% [markdown]
# # distplot()

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist = False)
sns.distplot(df[df['Survived']==1]['Age'], hist = False)

# sns.displot(titanic['Age'], color="b", kind="kde", label="Fitted Values")
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_12212\822719996.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist = False)
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_12212\822719996.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.displot(data=df, x='Age', hue='Survived', kind='kde', fill=False, palette={0: 'r', 1: 'g'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 sns.displot(data=df, x='Age', hue='Survived', kind='kde', fill=False, palette={0: 'r', 1: 'g'})
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2113, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2094 def displot(
#    2095     data=None, *,
#    2096     # Vector variables
#    (...)
#    2105     **kwargs,
#    2106 ):
#    2108     p = _DistributionPlotter(
#    2109         data=data,
#    2110         variables=dict(x=x, y=y, hue=hue, weights=weights, row=row, col=col),
#    2111     )
# -> 2113     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
df.Survived.unique()
# Out:
# array([0, 1, 2, 4])

# %% [markdown]
# # HeatMap (Categorical - Categorical)

# %%
# heatmap is used get the how the corrilation between the variables

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1  2  4
# Pclass
# 1          80  136  0  0
# 2          97   87  0  0
# 3         368  121  1  1

# %%
df.Survived.unique()
# Out:
# array([0, 1, 2, 4])

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 96            97         0       1
# 24            25         2       3
# 411          412         0       3
# 700          701         1       1
# 392          393         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 411                                    Hart, Mr. Henry    male   NaN      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 392                       Gustafsson, Mr. Johan Birger    male  28.0      2
#
#      Parch    Ticket      Fare    Cabin Embarked
# 96       0  PC 17754   34.6542       A5        C
# 24       1    349909   21.0750      NaN        S
# 411      0    394140    6.8583      NaN        Q
# 700      0  PC 17757  227.5250  C62 C64        C
# ...

# %% [raw]
# pd.crosstab() in pandas is used to compute a cross-tabulation (or contingency table), which is a way to summarize the relationship between two or more categorical variables. It essentially creates a table that shows the frequency of combinations of categories in the given variables.

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# # ClusterMap (Categorical - Categorical)

# %% [raw]
# A clustermap is a heatmap with hierarchical clustering, and it's a great way to visualize both the relationships between data points and the structure of clusters within the data. You can create a clustermap using the seaborn library in Python.

# %%
df['Parch'].unique()  # parentchild
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
pd.crosstab(df['Parch'],df['Survived'])
# Out:
# Survived    0    1  2  4
# Parch
# 0         443  234  0  1
# 1          51   66  1  0
# 2          40   40  0  0
# 3           2    3  0  0
# 4           4    0  0  0
# 5           4    1  0  0
# 6           1    0  0  0

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']), figsize=(5,5))

# %% [markdown]
# # pairplot

# %% [raw]
# this graph is very useful. which gives the relationship between all the numerical columns in the datafame

# %%
sns.pairplot(df, hue = 'Survived')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue = 'species')

# %% [markdown]
# # Lineplot (Numerical - Numerical)

# %% [raw]
# this graph is used when we have the tie series data
# on x axis we have the year, month or day

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new = flights.groupby('year')['passengers'].sum().reset_index()

# %%
sns.lineplot(x = new['year'],y = new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(values='passengers', index='month', columns='year', observed=False)
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.clustermap(flights.pivot_table(values='passengers', index='month', columns='year', observed=False))
