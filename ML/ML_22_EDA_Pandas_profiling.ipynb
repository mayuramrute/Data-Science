# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# from pandas_profiling import ProfileReport
from pydantic import PydanticUserError

# %%
import pandas as pd
from pandas_profiling import ProfileReport
from pydantic_settings import BaseSettings

# Load your DataFrame
df = pd.read_csv('train.csv')

# Generate the profile report
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# To display the report in a Jupyter notebook (if using one)
profile.to_notebook_iframe()

# Alternatively, you can export the report to an HTML file
profile.to_file('report.html')
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       3 from pydantic_settings import BaseSettings
#       5 # Load your DataFrame
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ...

# %%
from pydantic_settings import BaseSettings

# %%
from typing import Annotated

from pydantic import PydanticUserError, create_model

try:
    create_model('FooModel', foo=Annotated[str, 'NotFieldInfoValue'])
except PydanticUserError as exc_info:
    assert exc_info.code == 'create-model-field-definitions'

# %%
# !pip uninstall pandas-profiling

# %%
# !pydantic pip uninstall pydantic
