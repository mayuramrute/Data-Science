# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('cgpa')             #  labbeling to the index
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
X = df.iloc[:,0:1]  # in[ut column selection

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state=2)

# %%
X_train
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# ..    ...
# 43   7.66
# 22   6.14
# 72   7.78
# 15   7.25
# 168  8.65
#
# [160 rows x 1 columns]

# %%
y_train
# Out:
# 137    3.13
# 163    3.91
# 111    2.25
# 123    2.30
# 109    4.06
#        ...
# 43     2.76
# 22     2.30
# 72     3.62
# 15     3.23
# 168    3.52
# Name: package, Length: 160, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print('MAE = ', mean_absolute_error(y_test,y_pred))
# Out:
# MAE =  0.2884710931878175

# %%
print('MSE = ', mean_squared_error(y_test,y_pred))
# Out:
# MSE =  0.12129235313495527

# %%
print('R2_score = ', r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2_score =  0.780730147510384

# %%
print('RMSE = ', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE =  0.34827051717731616

# %% [markdown]
# # Adjusted r2 score

# %% [raw]
# adj r2 score = 1 - ((1-r2)*(n-1)/(n-p-1))
# n = no of rows
# p = no of cols

# %%
adjR2 = 1-((1- r2)*(y_test.shape[0] - 1)/ (y_test.shape[0]-1-1))

# %%
adjR2
# Out:
# 0.7749598882343415

# %% [markdown]
# # adjusted r2 affected by multipul cols (relavent and irrelavent)

# %%
new_df1 = df.copy()

# %%
new_df1['random_feature'] = np.random.random(200)

# %%
new_df1.head()
# Out:
#    cgpa  package  random_feature
# 0  6.89     3.26        0.683399
# 1  5.12     1.98        0.740596
# 2  7.82     3.25        0.295745
# 3  7.42     3.67        0.469848
# 4  6.94     3.57        0.950914

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])

# %%
new_df1 = new_df1[['cgpa','random_feature','package']]

# %%
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.683399     3.26
# 1  5.12        0.740596     1.98
# 2  7.82        0.295745     3.25
# 3  7.42        0.469848     3.67
# 4  6.94        0.950914     3.57

# %%
X = new_df1.iloc[:,0:2]

# %%
X
# Out:
#      cgpa  random_feature
# 0    6.89        0.683399
# 1    5.12        0.740596
# 2    7.82        0.295745
# 3    7.42        0.469848
# 4    6.94        0.950914
# ..    ...             ...
# 195  6.93        0.768974
# 196  5.89        0.911481
# 197  7.21        0.075019
# 198  7.63        0.116333
# 199  6.22        0.346609
#
# [200 rows x 2 columns]

# %%
y = new_df1.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (160, 2)

# %%
lr1 = LinearRegression()

# %%
lr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr1.predict(X_test)
y_pred
# Out:
# array([3.89959706, 3.06346768, 2.39476485, 2.55615895, 1.61135481,
#        1.7610691 , 2.04896904, 2.95680128, 3.79739082, 2.95311365,
#        4.05762415, 3.46341533, 2.92790926, 2.40277397, 3.16956268,
#        3.44443921, 1.95972424, 3.23840829, 2.99286836, 3.39901997,
#        2.55367159, 3.16032909, 2.85393071, 3.123713  , 3.71865313,
#        2.88699299, 3.45739116, 3.34271752, 3.96213906, 1.90773778,
#        3.68446269, 3.19470456, 3.75641999, 2.76973128, 2.82434328,
#        3.27638909, 3.52549951, 2.59037203, 2.64027174, 2.71451855])

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.12233566793718298

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.28966263228245487

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7788440642011571

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7788440642011571

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7668896892931116
